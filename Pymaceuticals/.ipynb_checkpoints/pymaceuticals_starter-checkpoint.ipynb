# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
df_mousestudy = mouse_metadata.merge(study_results, how='outer', on="Mouse ID")

# Display the data table for preview
df_mousestudy
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
num_of_mice = len(df_mousestudy["Mouse ID"].unique())
print(f"The number of mice is {num_of_mice}.")
# Out:
# The number of mice is 249.

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
df_mouse_with_duplicates = df_mousestudy[df_mousestudy.duplicated(subset = ['Mouse ID', 'Timepoint']) == True]
mouse_deleted = df_mouse_with_duplicates["Mouse ID"].unique()

# %%
# Optional: Get all the data for the duplicate mouse ID. 
df_mouse_with_duplicates
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

# Create a copy of original dataframe
df_mousestudy_cleaned = df_mousestudy.copy()

# Using for loop to traverse the mouse ID that can't be used because of duplicate data
for mouse in mouse_deleted:
    df_mousestudy_cleaned = df_mousestudy_cleaned.drop(df_mousestudy_cleaned[df_mousestudy_cleaned["Mouse ID"] == mouse].index)

# Preview of the cleaned data that will be used throughout
df_mousestudy_cleaned
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
new_num_of_mice = len(df_mousestudy_cleaned["Mouse ID"].unique())

print(f"The number of mice being studied after cleaning the data set is {new_num_of_mice}.")
# Out:
# The number of mice being studied after cleaning the data set is 248.

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

df_mean_tumor = df_mousestudy_cleaned[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").mean()
df_median_tumor = df_mousestudy_cleaned[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").median()
df_var_tumor = df_mousestudy_cleaned[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").var()
df_std_tumor = df_mousestudy_cleaned[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").std()
df_sem_tumor = df_mousestudy_cleaned[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").sem()

df_summ = df_mean_tumor.copy()
df_summ = df_summ.rename(columns={"Tumor Volume (mm3)" : "Mean of Tumor Volume (mm3)"})
df_summ["Median of Tumor Volume (mm3)"] = df_median_tumor["Tumor Volume (mm3)"]
df_summ["Variance of Tumor Volume (mm3)"] = df_var_tumor["Tumor Volume (mm3)"]
df_summ["Standard Deviation of Tumor Volume (mm3)"] = df_std_tumor["Tumor Volume (mm3)"]
df_summ["SEM of Tumor Volume (mm3)"] = df_sem_tumor["Tumor Volume (mm3)"]


df_summ
# Out:
#               Mean of Tumor Volume (mm3)  Median of Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                      40.675741                     41.557809
# Ceftamin                       52.591172                     51.776157
# Infubinol                      52.884795                     51.820584
# Ketapril                       55.235638                     53.698743
# Naftisol                       54.331565                     52.509285
# Placebo                        54.033581                     52.288934
# Propriva                       52.320930                     50.446266
# Ramicane                       40.216745                     40.673236
# Stelasyn                       54.233149                     52.431737
# Zoniferol                      53.236507                     51.818479
#
#               Variance of Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                          24.947764
# Ceftamin                           39.290177
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
df_mousestudy_cleaned[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").describe()
# Out:
#              Tumor Volume (mm3)                                             \
#                           count       mean       std        min        25%
# Drug Regimen
# Capomulin                 230.0  40.675741  4.994774  23.343598  37.685933
# Ceftamin                  178.0  52.591172  6.268188  45.000000  47.208427
# Infubinol                 178.0  52.884795  6.567243  36.321346  47.312353
# Ketapril                  188.0  55.235638  8.279709  45.000000  48.232987
# Naftisol                  186.0  54.331565  8.134708  45.000000  47.285874
# Placebo                   181.0  54.033581  7.821003  45.000000  47.459053
# Propriva                  148.0  52.320930  6.622085  45.000000  46.894328
# Ramicane                  228.0  40.216745  4.846308  22.050126  36.674635
# Stelasyn                  181.0  54.233149  7.710419  45.000000  48.047139
# Zoniferol                 182.0  53.236507  6.966589  45.000000  47.337876
#
#
#                     50%        75%        max
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Setting up the dataframe for the bar plot
mice_treatment = df_mousestudy_cleaned[["Mouse ID", "Drug Regimen"]]

# Dropping duplicates of the mouse ID to get the correct count of the mouse
mice_treatment = mice_treatment.drop_duplicates("Mouse ID")

# Count the number of mouse for each drug used
mice_treatment = mice_treatment.groupby("Drug Regimen").count()
mice_treatment = mice_treatment.rename(columns={"Mouse ID":"Mouse Count"})

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
mice_treatment.plot(kind = "bar");

plt.title("Number of Mice per Drug Regimen")

plt.show();
plt.tight_layout();

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
fig1, ax1 = plt.subplots(figsize=(5,5))
mice_treatment.plot(kind = "bar", color = 'r', ax=ax1)
ax1.set(ylabel = "Number of Mice",
        xlabel = "Drug Regimen",
        title = "Number of Mice per Drug Regimen");

# %%
# Setting up Dataframe for the pie plot
# Taking the Mouse ID column and the Sex to create a new dataframe
mice_gender = df_mousestudy_cleaned[["Mouse ID", "Sex"]]

# Drop the duplicate mouse ID to obtain the correct number of mice
mice_gender = mice_gender.drop_duplicates("Mouse ID")

# Counting the number of mice based on their sex
mice_gender = mice_gender.groupby("Sex").count()
mice_gender = mice_gender.rename(columns = {"Mouse ID":"Mouse Counts"})

# Reset the index to obtain Sex and Mouse ID column again
mice_gender_indexed = mice_gender.reset_index()

# Preparing label and data for the pie plot
gender = mice_gender_indexed["Sex"]
mice_count = mice_gender_indexed["Mouse Counts"]

mice_gender
# Out:
#         Mouse Counts
# Sex
# Female           123
# Male             125

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
mice_gender.plot.pie(subplots = True, figsize=(5,5), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022845EA0DC8>],
#       dtype=object)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
fig2, ax2 = plt.subplots(figsize = (5,5))
ax2.pie(mice_count, labels = gender, colors = ["red","lightskyblue"], autopct = "%1.2f%%");
ax2.set(title = "Mouse Study Gender Distribution");

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
